# %%
import pandas as pd
import mysql.connector as connector
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from PIL import Image as image
sns.set()

# %%
Model = image.open("ModelImage.png")
plt.figure(figsize=(36,24))
plt.imshow(Model)
plt.show()

# %%
ShoppingItems = image.open("Shopping.png")
plt.figure(figsize=(24,12))
plt.imshow(ShoppingItems)
plt.show()

# %%
videoItems = image.open("Video.png")
plt.figure(figsize=(24,12))
plt.imshow(videoItems)
plt.show()

# %%
musicItems = image.open("Music.png")
plt.figure(figsize=(24,12))
plt.imshow(musicItems)
plt.show()

# %%
conn = connector.connect(host="localhost", port="3306", user="root",
                                      password="07041997", database="ama_projectfinal")

# %%
Amazon=pd.read_sql_query("select * from amazon",conn)
Amazon
# Out:
#    Selection_ID Selection_Name
# 0             1       Shopping
# 1             2            Pay
# 2             3   Prime Videos
# 3             4    Prime Music

# %%
category=pd.read_sql_query("select * from category",conn)
category.head()
# Out:
#    Selection_ID  Category_ID      Category_Name
# 0             1            1       Echo & Alexa
# 1             1            2  Mobile & Computer
# 2             1            3    Sport & Luggage
# 3             1            4            Fashion
# 4             1            5        Electronics

# %%
sub_category=pd.read_sql_query("select * from sub_category",conn)
sub_category.head()
# Out:
#    Category_ID  Sub_Category_ID                         Sub_Category_Name
# 0            1                1  All-New Echo Dot (4th Gen, 2020 release)
# 1            1                3                               Echo Show 8
# 2            1                4                               Echo Studio
# 3            1                5                                Meet Alexa
# 4            1                6                          Alexa Smart Home

# %%
Shopping_ite=pd.read_sql_query("select * from shopping_items",conn)
Shopping_ite.head()
# Out:
#    Sub_Category_ID  Item_id                            Item_Name  Item_Price  \
# 0                1        1     Echo Dot (4th Gen, 2020 release)      3699.0
# 1                3        3  Echo Show 8 (1st Gen, 2020 release)      8999.0
# 2                4        4         Echo Studio - Smart speaker      22999.0
# 3                6        5           All-new Echo Dot (4th Gen)      3899.0
# 4                6        6           All-new Echo Dot (3rd Gen)      3149.0
#
#    Item_Rating  Total_Rating
# 0          4.4       24273.0
# 1          4.4        3894.0
# 2          4.2         729.0
# 3          4.5        3899.0
# 4          4.4        3199.0

# %%
prime_video=pd.read_sql_query("select * from prime_video_item",conn)
prime_video.head()
# Out:
#    Sub_Category_ID  Prime_Id             Name  Season  IMBD_Rating
# 0               61         1       Pataal Lok       1          7.5
# 1               61         2   Made in Heaven       1          8.3
# 2               61         3       Homecoming       2          7.5
# 3               61         4         Mirzapur       1          8.5
# 4               61         5  Man with a Plan       4          7.4

# %%
songs=pd.read_sql_query("select * from album_listing",conn)
songs.head()
# Out:
#    Prime_Music_Id                              Song_Name  \
# 0               5                            Chale Chalo
# 1               5  Lagaan..... Once Upon A Time In India
# 2               5                     Mitwa\tAlka Yagnik
# 3               5                          O Paalanhaare
# 4               5                            O Rey Chori
#
#                                         Artist        Duration
# 0                      A. R. Rahman & Srinivas 0 days 06:24:00
# 1                              Anuradha Sriram 0 days 04:07:00
# 2   Udit Narayan & Sukhwinder Singh & Srinivas 0 days 06:27:00
# 3               Lata Mangeshkar & Udit Narayan 0 days 05:10:00
# 4   Udit Narayan & Alka Yagnik & Vasundara Das 0 days 05:35:00

# %%
payment=pd.read_sql_query("select * from payment",conn)
payment.head()
# Out:
#    Payment_Id    Method Name
# 0           1    Credit Card
# 1           2           Cash
# 2           3         PayPal
# 3           4  Wire Transfer

# %%
order_status=pd.read_sql_query("select * from order_status",conn)
order_status.head()
# Out:
#    Order_Status_Id Status_Name
# 0                1   Processed
# 1                2     Shipped
# 2                3   Delivered

# %%
orders=pd.read_sql_query("select * from orders",conn)
orders.head()
# Out:
#    Log_in_ID  Order_Id  Payment_Id  Order_Status_Id  Item_id  Order_Quantity  \
# 0          1         1           2                1       37               1
# 1          1         2           3                2      137               3
# 2          1         3           3                3      537               3
# 3          1         4           4                1      360               7
# 4          1         5           1                3     1000               4
#
#    Order_Date
# 0  2019-01-03
# 1  2019-01-08
# 2  2019-01-08
# 3  2019-01-15
# 4  2019-01-26

# %%
prime_music=pd.read_sql_query("select * from prime_music_item",conn)
prime_music.head()
# Out:
#    Sub_Category_ID  Prime_Music_Id               Album               Composer
# 0               85               1        Udaan (2010)           Amit Trivedi
# 1               85               2    Guzaarish (2011)  Sanjay Leela Bhansali
# 2               85               3  Delhi Belly (2011)             Ram Sampat
# 3               85               4        Gunday(2012)             Sohail Sen
# 4               85               5              Laagan              AR Rehman

# %%
pay_item=pd.read_sql_query("select * from pay_item",conn)
pay_item.head()
# Out:
#    Sub_Category_ID  Pay_itemid          Item_name
# 0               39           1       New Recharge
# 1               39           2    Recent Recharge
# 2               46           4   New Train Ticket
# 3               46           5  New Flight Ticket
# 4               48           6      Car Insurance

# %%
conn = connector.connect(host="localhost", port="3306", user="root",
                                      password="07041997", database="ama_projectfinal")

# %%
conn

# %% [markdown]
# ### query3 = "CREATE TABLE materialized_view (SELECT * from amazon);"
# ### cur =conn.cursor()
# ### cur.execute(query3)

# %%
query4=pd.read_sql_query("select * from materialized_view",conn)

# %%
query4
# Out:
#    Selection_ID Selection_Name
# 0             1       Shopping
# 1             2            Pay
# 2             3   Prime Videos
# 3             4    Prime Music

# %% [markdown]
# Index on subcategory
# ## create index idx_sc on sub_category(category_id);##
# Index on shopping Item
# ## create index idx_catid on shopping_items(sub_category_id);##
# ## create index idx_vidid on shopping_items(sub_category_id);##

# %%
withoutindex = image.open("without index.png")
plt.figure(figsize=(36,24))
plt.imshow(withoutindex)
plt.show()

# %%
withindex = image.open("with index.png")
plt.figure(figsize=(36,24))
plt.imshow(withindex)
plt.show()

# %% [markdown]
# ### Index were used on large table to reduce the over all scanning of table when filter is used,by applying the index we can increase the speed of the query.
# ###  Explain keyword with the statement shows how the rows are scans in a table.
#       All keyword in key section of explain keyword employs all rows are scanned in the table.
#       Index name in key section employs the rows in column are scanned with the help of index.

# %%
query5=pd.read_sql_query("show index from shopping_items",conn)

# %%
query5
# Out:
#             Table  Non_unique                             Key_name  \
# 0  shopping_items           0                              PRIMARY
# 1  shopping_items           1  fk_Shopping Items_Sub_Category1_idx
# 2  shopping_items           1                            idx_catid
# 3  shopping_items           1                            idx_vidid
#
#    Seq_in_index      Column_name Collation  Cardinality Sub_part Packed Null  \
# 0             1          Item_id         A          881     None   None
# 1             1  Sub_Category_ID         A           31     None   None
# 2             1  Sub_Category_ID         A           31     None   None
# 3             1  Sub_Category_ID         A           31     None   None
#
#   Index_type Comment Index_comment Visible Expression
# 0      BTREE                           YES       None
# 1      BTREE                           YES       None
# 2      BTREE                           YES       None
# 3      BTREE                           YES       None

# %% [markdown]
# ## Trigger : For Auditing the new order & cancelled Order
# create table audit
# (log_in_id int not null,item_id int not null,order_date date not null,action_type varchar(50) not null
# )
# delimiter $$
# create trigger auditing
#  after insert on orders for each row
#  begin
#  insert into audit values(new.log_in_id,new.item_id,Now(),"New Order");
#  end $$
#  delimiter ;
#  delimiter $$
# create trigger del_auditing
#  after delete on orders for each row
#  begin
#  insert into audit values(old.log_in_id,old.item_id,Now(),"Order Cancelled");
#  end $$
#  delimiter ;

# %% [markdown]
# query9="insert into orders values  (2,7,4,2,12,2,'2021-03-24');"
# cur.execute(query9)

# %%
query10=pd.read_sql_query("select * from audit",conn)
query10
# Out:
#    log_in_id  item_id  order_date      action_type
# 0          1       11  2022-02-26        New Order
# 1          2       12  2022-02-26        New Order
# 2          2       12  2022-02-26  Order Cancelled

# %% [markdown]
# ## Stored Procedure :
# select * from orders;
# DELIMITER $$
# CREATE PROCEDURE orderg1
# (quan  int)
# BEGIN
#   SELECT * FROM orders
#   WHERE  order_quantity> quan;
# END $$
# DELIMITER ;
# CALL orderg1(1);
# #################
# DELIMITER $$
# CREATE PROCEDURE shopingpr
# (ratquan  float,itemprice int)
# BEGIN
#   SELECT * FROM shopping_items
#   WHERE  item_rating > ratquan and item_price > itemprice;
# END $$
# DELIMITER ;
# CALL shopingpr(4.4,12000);

# %%
query12=pd.read_sql_query("CALL shopingpr(4.4,12000);",conn)
query12
# Out:
#     Sub_Category_ID  Item_id  \
# 0                 8       41
# 1                 8       42
# 2                 8       43
# 3                 8       59
# 4                10      110
# 5                10      111
# 6                10      131
# 7                10      138
# 8                29      809
# 9                29      811
# 10               29      814
# 11               30      844
# 12               32      907
# 13               33      919
# 14               33      920
# 15               33      924
# 16               33      925
# 17               33      926
# 18               33      928
# 19               33      929
# 20               33      932
# 21               34      949
# 22               35      970
# 23               35      978
#
#                                             Item_Name  Item_Price  \
# 0   OnePlus Nord CE 2 5G (Bahamas Blue, 6GB RAM, 1...     23999.0
# 1   OnePlus Nord CE 2 5G (Gray Mirror, 6GB RAM, 12...     23999.0
# 2   OnePlus Nord CE 2 5G (Gray Mirror, 8GB RAM, 12...     24999.0
# 3   Samsung Galaxy Watch 3 45mm Bluetooth (Mystic ...     17990.0
# 4   2021 Apple 10.2-inch (25.91 cm) iPad with A13 ...     44900.0
# 5   2021 Apple iPadÿPro with Apple M1 chip (11-inc...     68490.0
# 6   realme Pad 4 GB RAM 64 GB ROM 10.4 inch with W...     18490.0
# 7   Samsung Galaxy Tab S7 FE 31.5 cm (12.4 inch) L...     39999.0
# 8             24k (999.9) 10 gm Lotus Yellow Gold Bar     58350.0
# 9              24k (999.9) 5 gm Lotus Yellow Gold Bar     29300.0
# 10  GGC Gujarat Gold Centre 24k (999) Yellow Gold ...     28459.0
# 11  Sansui 102 cm (40 inches) Full HD Certified An...     21490.0
# 12  Yamaha SR-C20A Compact Sound Bar with Built-in...     16836.0
# 13  Canon EOS 200D II 24.1MP Digital SLR Camera + ...     56499.0
# 14  Canon EOS 200D II 24.1MP Digital SLR Camera + ...     57648.0
# 15  Canon EOS 90D Digital SLR Camera with 18-135 i...    134990.0
# 16  Canon EOS 90D Digital SLR Camera with 18-135 i...    137759.0
# 17  Canon EOS M50 Mark II + EF-M 15-45mm is STM Ki...     25999.0
# 18  Nikon Digital Camera Z 5 Kit with NIKKOR Z 24-...     49990.0
# 19  Nikon Digital Camera Z 5 kit with NIKKOR Z 24-...    130990.0
# 20  Sony Alpha ILCE-7RM4A Full-Frame 61.0MP Mirror...    286990.0
# 21  Samsung 198 L 4 Star Inverter Direct-Cool Sing...     16550.0
# 22  Bosch 7 kg 5 Star Inverter Touch Control Fully...     30990.0
# 23  LG 7.5 Kg 5 Star Semi-Automatic Top Loading Wa...     13023.0
#
#     Item_Rating  Total_Rating
# 0           4.5          2324
# 1           4.5          2324
# 2           4.5          2324
# 3           4.5          2348
# 4           4.8           896
# 5           4.7          1155
# 6           4.5           199
# 7           4.5          1260
# 8           4.6           314
# 9           4.6           367
# 10          5.0             2
# 11          5.0             1
# 12          4.5           624
# 13          4.5          1127
# 14          4.5          1127
# 15          4.5            75
# 16          4.5            75
# 17          4.6           269
# 18          4.9             5
# 19          4.8            10
# 20          4.7           190
# 21          4.5             8
# 22          4.5          4197
# 23          4.5           594

# %%
conn = connector.connect(host="localhost", port="3306", user="root",
                                      password="07041997", database="ama_projectfinal")

# %%
query11=pd.read_sql_query("CALL orderg1(1);",conn)
query11
# Out:
#    Log_in_ID  Order_Id  Payment_Id  Order_Status_Id  Item_id  Order_Quantity  \
# 0          1         2           3                2      137               3
# 1          1         3           3                3      537               3
# 2          1         4           4                1      360               7
# 3          1         5           1                3     1000               4
#
#    Order_Date
# 0  2019-01-08
# 1  2019-01-08
# 2  2019-01-15
# 3  2019-01-26

# %% [markdown]
#  ### Matrialized View Using MYSQL:
#  query3 = "CREATE TABLE materialized_view (SELECT * from amazon);"
#  cur =conn.cursor()
#  cur.execute(query3)

# %%
conn = connector.connect(host="localhost", port="3306", user="root",
                                      password="07041997", database="ama_projectfinal")

# %%
query13=pd.read_sql_query("select * from materialized_view",conn)
query13
# Out:
#    Selection_ID Selection_Name
# 0             1       Shopping
# 1             2            Pay
# 2             3   Prime Videos
# 3             4    Prime Music

# %% [markdown]
# ## Matrialized View Using Oracle:
# create Materialized  View mat_select as
# select * from prime_video_item where IMBD_Rating>6.0;
# create Materialized  View mat_select as
# select *,rank() over (order by item_price ) as ranka from shopping_items ;
# create Materialized  View mat_select as
# select * from orders ;
